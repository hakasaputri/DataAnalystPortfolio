-- %% [markdown]
-- # [datacleaning]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [datacleaning]    Script Date: 16/05/2024 02:59:28 ******/
CREATE DATABASE [datacleaning]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'datacleaning', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\datacleaning.mdf' , SIZE = 73728KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'datacleaning_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\datacleaning_log.ldf' , SIZE = 204800KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [datacleaning] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [datacleaning].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [datacleaning] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [datacleaning] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [datacleaning] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [datacleaning] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [datacleaning] SET ARITHABORT OFF 
GO
ALTER DATABASE [datacleaning] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [datacleaning] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [datacleaning] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [datacleaning] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [datacleaning] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [datacleaning] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [datacleaning] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [datacleaning] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [datacleaning] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [datacleaning] SET  DISABLE_BROKER 
GO
ALTER DATABASE [datacleaning] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [datacleaning] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [datacleaning] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [datacleaning] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [datacleaning] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [datacleaning] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [datacleaning] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [datacleaning] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [datacleaning] SET  MULTI_USER 
GO
ALTER DATABASE [datacleaning] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [datacleaning] SET DB_CHAINING OFF 
GO
ALTER DATABASE [datacleaning] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [datacleaning] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [datacleaning] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [datacleaning] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [datacleaning] SET QUERY_STORE = ON
GO
ALTER DATABASE [datacleaning] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[NashvilleHousing]

-- %%
USE [datacleaning]
GO

-- %%
/****** Object:  Table [dbo].[NashvilleHousing]    Script Date: 16/05/2024 02:59:28 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NashvilleHousing](
	[UniqueID ] [float] NULL,
	[ParcelID] [nvarchar](255) NULL,
	[LandUse] [nvarchar](255) NULL,
	[PropertyAddress] [nvarchar](255) NULL,
	[SaleDate] [datetime] NULL,
	[SalePrice] [float] NULL,
	[LegalReference] [nvarchar](255) NULL,
	[SoldAsVacant] [nvarchar](255) NULL,
	[OwnerName] [nvarchar](255) NULL,
	[OwnerAddress] [nvarchar](255) NULL,
	[Acreage] [float] NULL,
	[TaxDistrict] [nvarchar](255) NULL,
	[LandValue] [float] NULL,
	[BuildingValue] [float] NULL,
	[TotalValue] [float] NULL,
	[YearBuilt] [float] NULL,
	[Bedrooms] [float] NULL,
	[FullBath] [float] NULL,
	[HalfBath] [float] NULL,
	[ConvertedDate] [date] NULL,
	[splitAddress] [nvarchar](225) NULL,
	[splitCity] [nvarchar](225) NULL,
	[OwnerSplitAddress] [nvarchar](225) NULL,
	[OwnerSplitCity] [nvarchar](225) NULL,
	[OwnerSplitState] [nvarchar](225) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [datacleaning]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [datacleaning] SET  READ_WRITE 
GO
