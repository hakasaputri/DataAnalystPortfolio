-- %% [markdown]
-- # [hakasa]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [hakasa]    Script Date: 16/05/2024 02:59:52 ******/
CREATE DATABASE [hakasa]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'hakasa', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\hakasa.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'hakasa_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\hakasa_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [hakasa] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [hakasa].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [hakasa] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [hakasa] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [hakasa] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [hakasa] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [hakasa] SET ARITHABORT OFF 
GO
ALTER DATABASE [hakasa] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [hakasa] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [hakasa] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [hakasa] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [hakasa] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [hakasa] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [hakasa] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [hakasa] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [hakasa] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [hakasa] SET  DISABLE_BROKER 
GO
ALTER DATABASE [hakasa] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [hakasa] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [hakasa] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [hakasa] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [hakasa] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [hakasa] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [hakasa] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [hakasa] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [hakasa] SET  MULTI_USER 
GO
ALTER DATABASE [hakasa] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [hakasa] SET DB_CHAINING OFF 
GO
ALTER DATABASE [hakasa] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [hakasa] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [hakasa] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [hakasa] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [hakasa] SET QUERY_STORE = ON
GO
ALTER DATABASE [hakasa] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[employees]

-- %%
USE [hakasa]
GO

-- %%
/****** Object:  Table [dbo].[employees]    Script Date: 16/05/2024 02:59:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[employees](
	[employee_id] [int] NOT NULL,
	[first_name] [varchar](50) NULL,
	[last_name] [varchar](50) NULL,
	[email] [varchar](50) NULL,
	[hire_date] [date] NULL,
	[gender] [varchar](1) NULL,
	[salary] [int] NULL,
	[coffeeshop_id] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[employee_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[locations]

-- %%
/****** Object:  Table [dbo].[locations]    Script Date: 16/05/2024 02:59:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[locations](
	[city_id] [int] NOT NULL,
	[city] [varchar](50) NULL,
	[country] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[city_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[shops]

-- %%
/****** Object:  Table [dbo].[shops]    Script Date: 16/05/2024 02:59:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[shops](
	[coffeeshop_id] [int] NOT NULL,
	[coffeeshop_name] [varchar](50) NULL,
	[city_id] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[coffeeshop_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[suppliers]

-- %%
/****** Object:  Table [dbo].[suppliers]    Script Date: 16/05/2024 02:59:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[suppliers](
	[coffeeshop_id] [int] NOT NULL,
	[supplier_name] [varchar](50) NOT NULL,
	[coffee_type] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[coffeeshop_id] ASC,
	[supplier_name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__employees__coffe__3A81B327]

-- %%
ALTER TABLE [dbo].[employees]  WITH CHECK ADD FOREIGN KEY([coffeeshop_id])
REFERENCES [dbo].[shops] ([coffeeshop_id])
ON DELETE SET NULL
GO

-- %% [markdown]
-- # [FK__shops__city_id__3D5E1FD2]

-- %%
ALTER TABLE [dbo].[shops]  WITH CHECK ADD FOREIGN KEY([city_id])
REFERENCES [dbo].[locations] ([city_id])
ON DELETE SET NULL
GO

-- %% [markdown]
-- # [FK__suppliers__coffe__403A8C7D]

-- %%
ALTER TABLE [dbo].[suppliers]  WITH CHECK ADD FOREIGN KEY([coffeeshop_id])
REFERENCES [dbo].[shops] ([coffeeshop_id])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [hakasa]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [hakasa] SET  READ_WRITE 
GO
